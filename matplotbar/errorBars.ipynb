# %%
"""
Title - Write a Python program to create bar plots with error bars on the same figure. Sample Date
        Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
        Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645
Author name - Aditya Kumar
Creation time - ‎‎15 ‎March ‎2021 ‏‎
Modified time - ‎‎‎15 ‎March ‎2021‎

"""


import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

index = (1,2,3,4)
mean_velo = (0.2474, 0.1235, 0.1737, 0.1824)
std_dev= (0.3314, 0.2278, 0.2836, 0.2645)

width = 0.1       # the width of the bars
plt.errorbar(index, mean_velo, color='r', yerr=std_dev, fmt = 'o', ecolor = 'k')

# add some text for labels, title and axes ticks
plt.ylabel('Scores')
plt.xlabel('Velocity')
plt.title('Scores by Velocity')



plt.show()
