# %%
"""
Title - Write a Python program to display the current axis limits values and set new axis values.
Author name - Aditya Kumar
Creation time - ‎‎13 ‎March ‎2021 ‏‎
Modified time - ‎‎‎13 ‎March ‎2021‎

"""

import matplotlib.pyplot as plt

# Data for the coordinates.
x = [1,4,5,6,7,8]
y = [2,16,23,6,87,66]

plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Draw a line.')


plt.plot(x, y)
# shows the current axis limits values
print(plt.axis())
# Out:
# (0.6499999999999999, 8.35, -2.25, 91.25)

# %%
plt.axis([0, 40, 0, 100]) 
# Display the figure.
plt.plot(x,y)
