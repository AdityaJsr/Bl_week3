# %%
"""
Title - Write a Python program to draw a line using given axis values with suitable label in the x axis, y axis and a title.
Author name - Aditya Kumar
Creation time - ‎‎13 ‎March ‎2021 ‏‎
Modified time - ‎‎‎13 ‎March ‎2021‎

"""
import matplotlib.pyplot as plt

x = [15,6,7,21,4,0,66,78]
y = [value * 3 for value in x]

print(x,y)
plt.title("Chainsmokers")
# plt.legend(labels)
plt.xlabel("Thsi is the X axis")
plt.ylabel("Thsi is the Y axis")
plt.plot(x, y)
# Out:
# [15, 6, 7, 21, 4, 0, 66, 78] [45, 18, 21, 63, 12, 0, 198, 234]
